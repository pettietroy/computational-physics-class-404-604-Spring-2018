# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np

# %%
print('Due 1/21')
# Out:
# Due 1/21

# %%
#plt.style.use('ggplot')
plt.style.use('fivethirtyeight')

# %%
n=1e-7
x = np.arange(-n,n,n/100)
y = (1-np.cos(x))/(x**2)

# %%
plt.title('Catastrophic Cancellation')
plt.plot(x,y)
